# %% [markdown]
# # XGBoost for Time-series data and Tabular data

# %% [markdown]
# - ensemble learning
#     1. Baggging : homogeneous weak learners
#     2. Boosting : homogeneous weak learners
#     3. Stacking : heterogenuos weak learners

# %% [markdown]
# # Review Decision Tree

# %% [markdown]
# - đối với những bộ dữ liệu quá phức tạp , decision tree sẽ học toàn bộ trainning data bao gồm cả các dữ liệu nhiễu sẽ dẫn đến việc bị overfitting (high variance) --> prunning

# %% [markdown]
# # Review Gradient Boosting

# %% [markdown]
# - Gradient descent + boosting
