# %% [markdown]
# # Decision Tree

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Rule based

# %% [markdown]
# ## Decision tree

# %% [markdown]
# - A general Decision Tree may contain many conditions and outcomes

# %% [markdown]
# ## Entropy

# %% [markdown]
# - entropy is used to measure disorder  , randomness or uncertainly

# %% [markdown]
# - entropy đo mức độ không chắc chắn trong 1 tập dữ liệu
# - entropy cao : dữ liệu hỗn loạn , khó đoán
# - entropy thấp : dữ liệu có trật tự , dễ đoán

# %% [markdown]
# # Classification tree

# %% [markdown]
# - entropy
# - infomation gain (IG)

# %% [markdown]
# - sử dụng thuật toán infomation gain(IG)
# - IG dùng để đo mức độ GIẢM của entropy khi chia dữ liệu theo 1 đặc trưng
