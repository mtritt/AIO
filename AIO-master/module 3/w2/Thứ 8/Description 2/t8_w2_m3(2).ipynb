# %% [markdown]
# # chữa bài tập

# %% [markdown]
# # K nearest neighbors and K - Means Clustering

# %% [markdown]
# ## KNN

# %% [markdown]
# - KNN is one of the simplest supervised machine learning algorithms
# - motivation : lazy learning

# %% [markdown]
# - Regression : predict a continuous value based on the input variables
# - Classification : classify input variables to indentify discrete output variables (labels categories)

# %% [markdown]
# - fearture scaling (normalization) : standardize the range of  independent variables (fearture of data)

# %% [markdown]
# - how to find k optimal value K in KNN : choose L based on the evaluation on the validation set

# %% [markdown]
# - KNN for text classification
# - BoW : bag of words
# - OOV : out of vocabulary
# - binary representation

# %% [markdown]
# # K - Means Clustering

# %% [markdown]
# - clustering is an unsupervised machine learning technique designed to group unlabeled examples
# - clustering is an unsupervised and classifier is an supervised learning

# %% [markdown]
# - limitations of KMeans : different size
# - limitations of KMeans : different density(tỉ trọng)
# - limitations of KMeans : non - spherical shape

# %% [markdown]
# - how to determine the optimal K for KMeans ?
# - WCSS (within cluster sum of square)
