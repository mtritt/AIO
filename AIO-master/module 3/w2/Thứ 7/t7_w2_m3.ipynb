# %% [markdown]
# # advance data visualization

# %% [markdown]
# - sử dụng 3 thư viện cơ bản cho visual data

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px

# %% [markdown]
# # ETTh dataset

# %% [markdown]
# - tại sao trong box plots lại là 1.5 * IQR : làm cho distribution gần giống với gaussian

# %% [markdown]
# # Student Performence dataset

# %% [markdown]
# # Iris dataset
