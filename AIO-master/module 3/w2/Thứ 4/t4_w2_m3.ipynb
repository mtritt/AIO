# %% [markdown]
# # machine learning

# %% [markdown]
# - supervised learning
# - unsupervised learning
# - reinforcement learning

# %% [markdown]
# - semi supervised

# %% [markdown]
# # KNN motivation

# %% [markdown]
# - one of the simplest algorihms

# %% [markdown]
# # KNN for classification

# %% [markdown]
# # How to select K in KNN

# %% [markdown]
# # KNN with brute force

# %% [markdown]
# # KNN for regression

# %% [markdown]
# - câu lệnh fit giúp thuật toán thực hiện nhanh hơn nhờ xây dựng 1 tree

# %% [markdown]
# # KNN with K-D tree

# %% [markdown]
# # data sience
