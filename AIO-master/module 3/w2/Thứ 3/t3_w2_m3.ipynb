# %% [markdown]
# # Introduction to KNN

# %% [markdown]
# ## basic KNN

# %% [markdown]
# ### machine learning

# %% [markdown]
# - machine learning is a field of study that gives computers the ability to learn without being explicity programed

# %% [markdown]
# ## K - nearest neighbors

# %% [markdown]
# ### overview

# %% [markdown]
# - B1 : look at the data
# - B2 : calculate distance
# - B3 : find neighbors
# - B4 : vote on labels

# %% [markdown]
# ## Scaling

# %% [markdown]
# ## text classification KNN

# %% [markdown]
# ## KNN regression

# %% [markdown]
# -
