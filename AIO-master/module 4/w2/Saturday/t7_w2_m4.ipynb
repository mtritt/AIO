# %% [markdown]
# # Non-linear regression

# %% [markdown]
# - supervised learning and continuous data

# %% [markdown]
# ## Linear regression using Gradient Descent

# %% [markdown]
# - SGD : thực hiện N lần chọn samples
# - mini batch : mỗi lần huấn luyện chọn ra m samples thực hiện việc training
# - batch : lấy m = N samples để huấn luyện

# %% [markdown]
# ### Optimal learning rate

# %% [markdown]
# ### Limitation

# %% [markdown]
# - the main disadvantages of this technique is that the model is linear (tuyến tính) in both the parameters and the features . This is very restrictive assumption , quite of the often data exhibits behaviours that are nonlinear in the features

# %% [markdown]
# ### Moving beyond linearity

# %% [markdown]
# # Polynomial Regression (Hồi Quy Đa Thức)

# %% [markdown]
# - 3 PP khác nhau : dựa vào định nghĩa tạo đặc trưng đa thức , scikit learn , scipy tìm đường cong fit với bộ dữ liệu
