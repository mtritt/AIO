# %% [markdown]
# # Vectorization for Linear Regression - Loss Function

# %% [markdown]
# - differentiable (khả vi) : một hàm f(x) được gọi là khả vi tại a nếu f'(a) tồn tại .

# %% [markdown]
# ## Mean Absolute Error (MAE)

# %% [markdown]
# ## Huber loss

# %% [markdown]
# - nếu là ouliers thì nên sử dụng hàm loss MAE

# %% [markdown]
# - MSE is better when working with a fixed learning rate

# %% [markdown]
# - khả vi là khi hàm đó tồn tại đạo hàm ở tất cả các điểm

# %% [markdown]
# # Data Normalization
