# %% [markdown]
# # A Brigde to Linear Regression

# %% [markdown]
# # Optimization

# %% [markdown]
# - sử dụng gradient descent

# %% [markdown]
# - xt = x(t-1) - n*f'(x)

# %% [markdown]
# ## Observation 1

# %% [markdown]
# ## Observation 2

# %% [markdown]
# - 2D function
#     - x = x - n*đạo_hàm(x)
#     - y = y - n*đạo_hàm(y)

# %% [markdown]
# ## Observation 3

# %% [markdown]
# - for composite function

# %% [markdown]
# - dg/dx = dg/df * df/dx
