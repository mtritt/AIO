# %% [markdown]
# # text - image retrieval

# %% [markdown]
# ## introduce to image retrieval
# - Definition: The content based image retrieval aims to find the similar images from a large scale dataset against a query image. Generally, the similarity between the representative features of the query image and dataset images is used to rank the images for retrieval. In early days, various hand designed feature descriptors have been investigated based on the visual cues such as color, texture, shape, etc. that represent the images. However, the deep learning has emerged as a dominating alternative of hand-designed feature engineering from a decade. It learns the features automatically from the data

# %% [markdown]
# <img src="/Users/macos/AIO/module 2 /w5/T6/Solution/Ảnh màn hình 2025-12-15 lúc 23.20.16.png" width="600" alt="Mô tả ảnh">

# %% [markdown]
# <img src="/Users/macos/AIO/module 2 /w5/T6/Solution/Ảnh màn hình 2025-12-15 lúc 23.22.44.png" width="600" alt="Mô tả ảnh">

# %% [markdown]
# ### project pipeline

# %% [markdown]
# <img src="/Users/macos/AIO/module 2 /w5/T6/Solution/Ảnh màn hình 2025-12-15 lúc 23.25.49.png" width="600" alt="Mô tả ảnh">

# %% [markdown]
# ## Similarity Measurement Techniques in Image Retrieval

# %% [markdown]
# ### Distance Metrics and Similarity
# #### Distance Metrics:
# - Definition: Mathematical measures used to calculate the distance (or similarity) between two elements in a vector space.
#
# - Purpose: Evaluate how far apart or how similar two elements are.
#
# 1.Context of Embeddings:
# - Definition: Embeddings are vector representations of data points.
#
# - Role of Distance Metrics: In this context, distance metrics are used to assess the similarity between embeddings.
#
# 2.Similarity Query Search:
# - Function: Retrieves embeddings that are similar to a given input.
#
# - Based On: Uses distance metrics to determine which embeddings are close to the input in the vector space.

# %% [markdown]
# ### distance metrics
# 1.manhattan distance L1
# - lấy toạ độ x - x , y - y , lấy trị tuyệt đối và cộng tổng 2 kết quả
# - đo từ toạ độ A sang B bằng cách đi từ hoành độ sang tung độ hoặc ngươc lại
#
# 2.euclidean distance L2
# - tương tự cách tính độ dài vector
#
# 3.cosine similarity
# - tính toán sự tương đồng giữa 2 vectors

# %% [markdown]
# ----

# %% [markdown]
# 1.Euclidean Distance:
# - Definition: Measures the straight-line distance between two points in Euclidean space.
# - Use Case: Used to determine how far apart two points are in a straight line, considering both the magnitude and direction of the vectors.
#
# 2.Manhattan Distance (L1 Norm):
# - Definition: Sums the absolute differences of the coordinates of two points.
#
# - Use Case: Measures distance by moving along grid lines, often used in contexts where movements are restricted to orthogonal directions.
#
# 3.Cosine Similarity:
# Definition: Measures the cosine of the angle between two vector embeddings.
#
# - Use Case: Commonly used in text analysis and other domains where the direction of the vector is more important than its magnitude.

# %% [markdown]
# - LƯU Ý : correlation chỉ có thể xác định mối quan hệ tuyến tính hay không

# %% [markdown]
# ## data preparation for image retrieval

# %% [markdown]
# -

# %% [markdown]
# ## basic image retrieval system

# %% [markdown]
# 1.manhattan distance L1

# %% [markdown]
# <img src="/Users/macos/AIO/module 2 /w5/Ảnh màn hình 2025-12-17 lúc 00.17.42.png" width="600" alt="Mô tả ảnh">

# %% [markdown]
# - manhattan distance L1 có nhược điểm về ánh sáng , nếu là bức ảnh giống hệt nhưng độ sáng giảm xuống cũng có thể ảnh hưởng đến tính toán sự tương đồng

# %% [markdown]
# 2.Euclidean distance L2

# %% [markdown]
# <img src="/Users/macos/AIO/module 2 /w5/Ảnh màn hình 2025-12-17 lúc 00.36.44.png" width="600" alt="Mô tả ảnh">

# %% [markdown]
# - nhược điểm cũng tương tự như L1

# %% [markdown]
# 3.Cosine similarity

# %% [markdown]
# <img src="/Users/macos/AIO/module 2 /w5/Ảnh màn hình 2025-12-17 lúc 00.41.58.png" width="600" alt="Mô tả ảnh">

# %% [markdown]
# - khắc phục được nhược điểm của L1 và L2
# - không quan tâm về độ lớn mà quan tâm về hướng của vector hơn

# %% [markdown]
# ## Advanced Image Retrieval Using Pre-trained Deep Learning Model

# %% [markdown]
# <img src="/Users/macos/AIO/module 2 /w5/Ảnh màn hình 2025-12-17 lúc 00.45.26.png" width="600" alt="Mô tả ảnh">

# %% [markdown]
# <img src="/Users/macos/AIO/module 2 /w5/Ảnh màn hình 2025-12-17 lúc 00.46.00.png" width="600" alt="Mô tả ảnh">

# %% [markdown]
# ## implementing image retrieval with vector database

# %% [markdown]
# ### overview of vector database

# %% [markdown]
# <img src="/Users/macos/AIO/module 2 /w5/Ảnh màn hình 2025-12-17 lúc 00.58.31.png" width="600" alt="Mô tả ảnh">

# %% [markdown]
# - vector database : Là biểu diễn số (thường là mảng số thực) của dữ liệu (văn bản, hình ảnh, âm thanh, video) trong không gian đa chiều.
# - Vector càng gần nhau trong không gian → nội dung càng tương tự.

# %% [markdown]
# - Truy vấn theo độ tương tự (similarity search): Tìm các vector "giống nhất" với vector truy vấn.
#
# - Hiệu năng cao: Các CSDL thông thường (SQL/NoSQL) không tối ưu cho phép tính khoảng cách giữa các vector.
#
# - Scale tốt: Hỗ trợ hàng triệu đến hàng tỉ vector.
#
# - Hỗ trợ ANN (Approximate Nearest Neighbor): Tìm "hàng xóm gần nhất" một cách nhanh chóng, đánh đổi độ chính xác để tăng tốc độ.
