# %% [markdown]
# # subqueries , procedure , trigger , pyspark
# - procedure tương tự như function

# %% [markdown]
# ## common table expression (with)

# %% [markdown]
# ## subqueries

# %% [markdown]
# ## temp table

# %% [markdown]
# ## store procedures

# %% [markdown]
# ## trigger

# %% [markdown]
# ## pyspark
