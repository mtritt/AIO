# %% [markdown]
# # naive bayes classifiers

# %% [markdown]
# ## review
# - biến cố độc lập : independent : P(AB) = P(A).P(B)
# - total probability theorem

# %% [markdown]
# ## multiple features

# %% [markdown]
# ## gaussian function
# - µ(muy) : mean
# - var(variance)

# %% [markdown]
# ### ứng dụng gaussian function cho image smoothing
# - bilateral filter : dungg thêm thông tin pixel color để hoạt động tốt hơn cho viền/cạnh
# - central limit theorem :

# %% [markdown]
# ### gaussian naive bayes classfifiers
# - biến số liên tục (continuous variable)
# - biến phân loại (categorical variable)
