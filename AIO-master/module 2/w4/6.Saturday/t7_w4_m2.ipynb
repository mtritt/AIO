# %% [markdown]
# # SQL for big data

# %% [markdown]
# ## introduction
# - definition : a collection of datasets that is large  , complex that make it very difficult to process using traditional data processing applications
# ----
# - big data characteristics (3V , 5V , 7V) : 5V
# - volume : khối lượng dữ liệu
# - variety : đa dạng dữ liệu
# - veracity : độ chính xác , sự tin cậy và sự đúng đắn của data
# - value : lợi ích mà data mang lại
# - velocity : tốc độ sinh trưởng của data
# ----
# - big data applications : healthcare , finance , retail , education , telecom , e-comerce

# %% [markdown]
# #### tools for big data
# 1.hadoop
# - an open-source framework that is used to efficently store and process large datasets ranging in size from gigabytes to petabytes of data
# - hadoop ecosystem : Hadoop HDFS (Hadoop Distributed File System): A distributed file system that handles larger data sets running on commodity hardware.
# - hadoop yarn : Hadoop YARN (Yet Another Resource Negotiator) the resources management and job scheduling technology.
# - Hadoop MapReduce: A highly sufficient methodology for parallel processing of huge volumes of data.
# - terminology : node , rack , cluster
# - hadoop architecture : mapreduce layer , HDFS layer

# %% [markdown]
# 1.1. HDFS layer
# - Namenode: Master node in a Hadoop cluster, managing file system’s metadata.
# - Datanode: Worker node in a Hadoop cluster, storing data blocks.
# - Blocks: A fixed-size chunk of data. Default is 128MB (or 64MB) size.

# %% [markdown]
# 1.1.2. hadoop mapreduce
# - Hadoop MapReduce: A distributed programming model and framework that breaks down large-scale data processing tasks into smaller, parallelizable operations (map and reduce), allowing for efficient processing and analysis of big data across a cluster of machines.

# %% [markdown]
# 1.1.3 installation
# - Hadoop Single Node (Hadoop pseudo-distributed mode): A configuration option in Hadoop that allows us to run Hadoop on a single machine.

# %% [markdown]
# 2.Spark
# - Apache Spark: an open-source unified analytics engine for large-scale data processing. Spark is an alternative replacement for Hadoop MapReduce.

# %% [markdown]
# 3.PySpark
# 3.1 introduction
# - PySpark: The Python API for Apache Spark. It enables to perform real-time, large-scale data processing in a distributed environment using Python.
