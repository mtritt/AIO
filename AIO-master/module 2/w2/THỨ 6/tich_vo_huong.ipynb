# %% [markdown]
# # bản chất của tích vô hướng
# - tích vô hướng chính là đo "sự giống nhau có hướng"

# %% [markdown]
# a. đo lường sự thẳng hàng
# - Khi hai vectơ cùng hướng (
# θ
# =
# 0
# ∘
# θ=0
# ∘
#  ,
# cos
# ⁡
# (
# 0
# )
# =
# 1
# cos(0)=1): Tích vô hướng đạt giá trị dương lớn nhất
# ∥
# a
# ∥
# ∥
# b
# ∥
# ∥a∥∥b∥. Chúng "giống nhau" nhất có thể.

# %% [markdown]
# - Khi hai vectơ ngược hướng (
# θ
# =
# 180
# ∘
# θ=180
# ∘
#  ,
# cos
# ⁡
# (
# 180
# )
# =
# −
# 1
# cos(180)=−1): Tích vô hướng đạt giá trị âm lớn nhất
# −
# ∥
# a
# ∥
# ∥
# b
# ∥
# −∥a∥∥b∥. Chúng "đối nghịch" nhau nhất.

# %% [markdown]
# - Khi hai vectơ vuông góc (
# θ
# =
# 90
# ∘
# θ=90
# ∘
#  ,
# cos
# ⁡
# (
# 90
# )
# =
# 0
# cos(90)=0): Tích vô hướng bằng 0. Chúng "không liên quan" gì đến nhau.

# %% [markdown]
# b. phép chiếu(projection)
# - Tích vô hướng chính là độ dài của hình chiếu của vectơ
# a
# a lên đường thẳng chứa vectơ
# b
# b, nhân với độ dài của
# b
# b.

# %% [markdown]
# c. tính góc giữa 2 vector
